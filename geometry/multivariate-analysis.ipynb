# %% [markdown]
# # multivariate exploration of the geometry corpus
#
# This is basicaly a raw exploration of the various info we can get from our corpus about wikipedia pages linked by the [`List of geometry topics` page](http://en.wikipedia.org/wiki/List_of_geometry_topics?oldformat=true). The aim of this study is to build an indicator allowing us to order pages by difficulty level.

# %%
# -*- coding: utf-8 -*-
# %matplotlib inline

# import json
import codecs

import math

import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# network = json.load(codecs.open("data/wikipedia-geometry/network.json","r", "utf-8-sig"))
# specialization = json.load(codecs.open("data/wikipedia-geometry/specialization.json","r", "utf-8-sig"))

# print network

# print len(network["nodes"])

# %% [markdown]
# ## data source preview

# %%
# for n in network["nodes"]:
#     titles.append(n["id"])

table = pd.read_csv("data/wikipedia-geometry/final.csv", encoding="UTF-8")
network_stats = pd.read_csv("data/wikipedia-geometry/pages-linked-by-coeditors.stats.csv", encoding="UTF-8")

#table.head(25) ## always this stupid utf-8 problem...

table = table.set_index("pagename")
network_stats = network_stats.set_index("pagename")
table = table.join(network_stats)


table.head(10)
# Out:
#                       average word length        first revision  hidden users  \
# pagename
# 2D computer graphics             5.912321  2001-10-13T06:23:27Z             0
# 3D computer graphics             6.360368  2007-03-21T05:56:20Z             0
# 3-sphere                         5.071429  2002-02-19T11:12:25Z             0
# Affine geometry                  5.424357  2003-06-11T09:28:43Z             0
# Algebraic geometry               5.734462  2002-02-25T15:51:15Z             0
# Altitude (triangle)              5.543959  2002-12-24T06:11:40Z             0
# Analytic geometry                5.544270  2002-02-25T15:51:15Z             0
# Angle                            5.132834  2002-02-25T15:43:11Z             0
# Angle trisection                 5.515563  2002-09-25T07:26:51Z             0
# Aperiodic tiling                 6.034483  2004-07-30T22:12:36Z             0
#
#                       length  number of backlinks  \
# pagename
# 2D computer graphics   24124                    0
# 3D computer graphics    8803                    0
# 3-sphere               17595                    0
# Affine geometry        15245                    0
# Algebraic geometry     46919                 1375
# Altitude (triangle)    12728                    0
# Analytic geometry      29122                    0
# Angle                  32780                    0
# Angle trisection       14862                    0
# Aperiodic tiling       18972                    0
#
#                       number of backlinks from ns 0  number of categories  \
# pagename
# 2D computer graphics                              0                     7
# 3D computer graphics                              0                     8
# 3-sphere                                          0                     7
# Affine geometry                                   0                     1
# Algebraic geometry                             1009                     1
# Altitude (triangle)                               0                     2
# Analytic geometry                                 0                     1
# Angle                                             0                    11
# Angle trisection                                  0                     7
# Aperiodic tiling                                  0                     2
#
#                       number of links  number of revisions  \
# pagename
# 2D computer graphics              403                  370
# 3D computer graphics              195                  893
# 3-sphere                          116                  277
# Affine geometry                    97                  205
# Algebraic geometry                379                  626
# Altitude (triangle)                59                  356
# Analytic geometry                 193                  477
# Angle                             192                 1742
# Angle trisection                  163                  434
# Aperiodic tiling                  227                  277
#
#                       number of revisions by IP        ...          \
# pagename                                               ...
# 2D computer graphics                        124        ...
# 3D computer graphics                        368        ...
# 3-sphere                                     59        ...
# Affine geometry                              40        ...
# Algebraic geometry                          189        ...
# Altitude (triangle)                         158        ...
# Analytic geometry                           191        ...
# Angle                                       704        ...
# Angle trisection                            110        ...
# Aperiodic tiling                             62        ...
#
#                       unique registered users  unique users  words  \
# pagename
# 2D computer graphics                      139           221   3490
# 3D computer graphics                      240           498   1196
# 3-sphere                                  117           161   2898
# Affine geometry                            82           112   2373
# Algebraic geometry                        213           366   6967
# Altitude (triangle)                       128           245   1945
# Analytic geometry                         176           326   4450
# Angle                                     468           952   5345
# Angle trisection                          127           194   2281
# Aperiodic tiling                          104           145   2697
#
#                       centrality  closeness  betweenness  \
# pagename
# 2D computer graphics           1          1     0.015467
# 3D computer graphics           1          1     0.000000
# 3-sphere                       1          1     0.000000
# Affine geometry                1          1     0.000000
# Algebraic geometry             1          1     0.000000
# Altitude (triangle)            1          1     0.000000
# Analytic geometry              1          1     0.000000
# Angle                          1          1     0.000000
# Angle trisection               1          1     0.000000
# Aperiodic tiling               1          1     0.000000
#
#                       current flow closeness  current flow betweenness  \
# pagename
# 2D computer graphics                6.222645                  0.004381
# 3D computer graphics                8.099603                  0.006997
# 3-sphere                            7.858913                  0.007360
# Affine geometry                     7.645164                  0.007084
# Algebraic geometry                  9.725693                  0.011190
# Altitude (triangle)                 8.111066                  0.007296
# Analytic geometry                   9.652685                  0.010609
# Angle                              11.073551                  0.015027
# Angle trisection                    7.771890                  0.006744
# Aperiodic tiling                    6.941009                  0.006254
#
#                       eigenvector  exclusive editors
# pagename
# 2D computer graphics     0.039955                 99
# 3D computer graphics     0.065823                143
# 3-sphere                 0.052748                 99
# Affine geometry          0.048833                 69
# Algebraic geometry       0.092190                169
# Altitude (triangle)      0.061286                 98
# Analytic geometry        0.092383                141
# Angle                    0.151483                334
# Angle trisection         0.054907                 89
# Aperiodic tiling         0.040444                 81
#
# [10 rows x 25 columns]

# %% [markdown]
# ## analysis

# %% [markdown]
# ### raw distribution of specialization
#
# The specialization indicator ($spe(wp,d)$) is a first attempt at quantifying the difficulty of pages.
#
# - $n_{wp}$ is the number of revisions by registered users
# - $i_{wp}$ is the number of revisions by unregistered users (IP)
# - $P(d,v)$
#
# \begin{align}
# spe(wp, d) = \frac{ P(d, n_wp) - P(d,i_wp) }{ |d| + 1 }
# \end{align}

# %%
table.hist("specialization")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x109087c10>]], dtype=object)

# %% [markdown]
# ## correlation matrix

# %%
f, ax = plt.subplots(figsize=(16, 10))
sns.corrplot(table,diag_names=False)

# %% [markdown]
# ### links x specialization

# %%
table.hist("number of links")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1099e1e90>]], dtype=object)

# %%
sns.jointplot(table.specialization, table["number of links"])

# %% [markdown]
# ## quality

# %%
table.hist("quality of the article")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10a399310>]], dtype=object)

# %%
g = sns.factorplot("quality of the article", "specialization", data=table, kind="bar")
#g.despine()

g
#sns.jointplot(table.specialization, table["quality of the article"])

# %% [markdown]
# ## word lengths

# %%
g = sns.factorplot("quality of the article", "average word length", data=table, kind="bar")

# %%
table.hist("average word length")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10a75d850>]], dtype=object)

# %%
sns.jointplot(table.specialization, table["length"])

# %%
sns.violinplot(table["average word length"], [ math.ceil(x * 10) for x in table["specialization"]])

# %%
sns.violinplot(table["length"], [ math.ceil(x * 10) for x in table["specialization"]])

# %% [markdown]
# ## length x revisions

# %%
sns.jointplot("number of revisions", "length", data=table[table["number of revisions"] < 500])

# %% [markdown]
# ## revisions x users

# %%
table["revisions / users"] = table["number of revisions"] / table["unique users"]

# %%
table.hist("revisions / users")
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10b7bb850>]], dtype=object)

# %%
sns.jointplot(table.specialization, table["revisions / users"])

# %%
sns.violinplot(table["revisions / users"], [ math.ceil(x * 10) for x in table["specialization"]])

# %% [markdown]
# ## page views

# %%
table.hist("page views", bins=20)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10e7cae50>]], dtype=object)
